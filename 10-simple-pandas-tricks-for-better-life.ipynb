# %% [markdown]
# <a href="https://www.kaggle.com/code/muhammedtausif/10-simple-pandas-tricks-for-better-life?scriptVersionId=123404820" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <p style="background-color:red; font-size:70px; text-align:center; padding:30px; color: yellow; border-radius:30px">10 Simple 🐼 Pandas Tricks for better Life 👻</p>
#
# That's a bit of an exaggeration but these tips are very helpful in a lot of different cases.
# 1. ✅ Selecting a Type of Column
# 2. 🌈 DataFrame Formatting
# 3. 🔘 DateTime Rounding Off

# %% [markdown]
# importing pandas as pd, and os

# %%
import pandas as pd 
import os

# %%
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %% [markdown]
# Reading the data from *train.csv* file

# %%
train = pd.read_csv("/kaggle/input/tabular-playground-series-mar-2022/train.csv")

# %% [markdown]
# Printing the first **5** records with head() function

# %%
train.head()
# Out:
#    row_id                 time  x  y direction  congestion
# 0       0  1991-04-01 00:00:00  0  0        EB          70
# 1       1  1991-04-01 00:00:00  0  0        NB          49
# 2       2  1991-04-01 00:00:00  0  0        SB          24
# 3       3  1991-04-01 00:00:00  0  1        EB          18
# 4       4  1991-04-01 00:00:00  0  1        NB          60

# %% [markdown]
# Printing the last 5 records with head() function

# %%
train.tail()
# Out:
#         row_id                 time  x  y direction  congestion
# 848830  848830  1991-09-30 11:40:00  2  3        NB          54
# 848831  848831  1991-09-30 11:40:00  2  3        NE          28
# 848832  848832  1991-09-30 11:40:00  2  3        SB          68
# 848833  848833  1991-09-30 11:40:00  2  3        SW          17
# 848834  848834  1991-09-30 11:40:00  2  3        WB          24

# %% [markdown]
# # 1. Getting Numeric and Categorical Columns

# %% [markdown]
# Print the **data type** of the *colums*

# %%
train.dtypes
# Out:
# row_id         int64
# time          object
# x              int64
# y              int64
# direction     object
# congestion     int64
# dtype: object

# %% [markdown]
# Print the *columns* with data type **int64**

# %%
train.select_dtypes('int64')
# Out:
#         row_id  x  y  congestion
# 0            0  0  0          70
# 1            1  0  0          49
# 2            2  0  0          24
# 3            3  0  1          18
# 4            4  0  1          60
# ...        ... .. ..         ...
# 848830  848830  2  3          54
# 848831  848831  2  3          28
# 848832  848832  2  3          68
# 848833  848833  2  3          17
# 848834  848834  2  3          24
#
# [848835 rows x 4 columns]

# %% [markdown]
# Print the name of *columns* with type **object**

# %%
f"Categorical Columns {train.select_dtypes('object').columns.tolist()}"
# Out:
# "Categorical Columns ['time', 'direction']"

# %% [markdown]
# Print the name of *columns* with data type **int64**

# %%
f"Numeric Columns {train.select_dtypes('int64').columns.tolist()}"
# Out:
# "Numeric Columns ['row_id', 'x', 'y', 'congestion']"

# %% [markdown]
# Print the first five entries of the columns with data type **object**

# %%
train.select_dtypes('object').head()
# Out:
#                   time direction
# 0  1991-04-01 00:00:00        EB
# 1  1991-04-01 00:00:00        NB
# 2  1991-04-01 00:00:00        SB
# 3  1991-04-01 00:00:00        EB
# 4  1991-04-01 00:00:00        NB

# %% [markdown]
# Doc - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.select_dtypes.html

# %% [markdown]
# # 2. DataFrame Formatting

# %%
train.select_dtypes('int64').head(10).style.background_gradient(cmap='RdPu') #Pastel2 #YlOrRd #RdPu
# Out:
# <style type="text/css">
# #T_b92b7_row0_col0, #T_b92b7_row0_col1, #T_b92b7_row0_col2, #T_b92b7_row1_col1, #T_b92b7_row1_col2, #T_b92b7_row2_col1, #T_b92b7_row2_col2, #T_b92b7_row3_col1, #T_b92b7_row3_col3, #T_b92b7_row4_col1, #T_b92b7_row5_col1, #T_b92b7_row6_col1, #T_b92b7_row7_col1, #T_b92b7_row8_col1, #T_b92b7_row9_col1 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_b92b7_row0_col3, #T_b92b7_row7_col2, #T_b92b7_row8_col2, #T_b92b7_row9_col0, #T_b92b7_row9_col2 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_b92b7_row1_col0 {
#   background-color: #fde3e0;
#   color: #000000;
# }
# #T_b92b7_row1_col3, #T_b92b7_row8_col3 {
#   background-color: #e34099;
#   color: #f1f1f1;
# }
# #T_b92b7_row2_col0 {
#   background-color: #fcccc7;
#   color: #000000;
# }
# #T_b92b7_row2_col3 {
#   background-color: #fde2df;
#   color: #000000;
# }
# #T_b92b7_row3_col0 {
#   background-color: #fbacb9;
#   color: #000000;
# }
# #T_b92b7_row3_col2, #T_b92b7_row4_col2, #T_b92b7_row5_col2, #T_b92b7_row6_col2 {
#   background-color: #f767a1;
#   color: #f1f1f1;
# }
# #T_b92b7_row4_col0 {
#   background-color: #f881aa;
#   color: #f1f1f1;
# }
# #T_b92b7_row4_col3 {
#   background-color: #96017b;
#   color: #f1f1f1;
# }
# #T_b92b7_row5_col0 {
#   background-color: #eb509c;
#   color: #f1f1f1;
# }
# #T_b92b7_row5_col3 {
#   background-color: #a6017d;
#   color: #f1f1f1;
# }
# #T_b92b7_row6_col0 {
#   background-color: #cd238f;
#   color: #f1f1f1;
# }
# #T_b92b7_row6_col3 {
#   background-color: #fddad7;
#   color: #000000;
# }
# #T_b92b7_row7_col0 {
#   background-color: #a1017c;
#   color: #f1f1f1;
# }
# #T_b92b7_row7_col3 {
#   background-color: #fcc5c0;
#   color: #000000;
# }
# #T_b92b7_row8_col0 {
#   background-color: #740175;
#   color: #f1f1f1;
# }
# #T_b92b7_row9_col3 {
#   background-color: #ef599e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b92b7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >row_id</th>
#       <th class="col_heading level0 col1" >x</th>
#       <th class="col_heading level0 col2" >y</th>
#       <th class="col_heading level0 col3" >congestion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b92b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b92b7_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_b92b7_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_b92b7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_b92b7_row0_col3" class="data row0 col3" >70</td>
#     </tr>
#     <tr>
#       <th id="T_b92b7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b92b7_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_b92b7_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_b92b7_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_b92b7_row1_col3" class="data row1 col3" >49</td>
#     </tr>
#     <tr>
#       <th id="T_b92b7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b92b7_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_b92b7_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_b92b7_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_b92b7_row2_col3" class="data row2 col3" >24</td>
#     </tr>
#     <tr>
#       <th id="T_b92b7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b92b7_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_b92b7_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_b92b7_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_b92b7_row3_col3" class="data row3 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_b92b7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b92b7_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_b92b7_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_b92b7_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_b92b7_row4_col3" class="data row4 col3" >60</td>
#     </tr>
#     <tr>
#       <th id="T_b92b7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b92b7_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_b92b7_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_b92b7_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_b92b7_row5_col3" class="data row5 col3" >58</td>
#     </tr>
#     <tr>
#       <th id="T_b92b7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b92b7_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_b92b7_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_b92b7_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_b92b7_row6_col3" class="data row6 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_b92b7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b92b7_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_b92b7_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_b92b7_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_b92b7_row7_col3" class="data row7 col3" >31</td>
#     </tr>
#     <tr>
#       <th id="T_b92b7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b92b7_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_b92b7_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_b92b7_row8_col2" class="data row8 col2" >2</td>
#       <td id="T_b92b7_row8_col3" class="data row8 col3" >49</td>
#     </tr>
#     <tr>
#       <th id="T_b92b7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b92b7_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_b92b7_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_b92b7_row9_col2" class="data row9 col2" >2</td>
#       <td id="T_b92b7_row9_col3" class="data row9 col3" >46</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #

# %% [markdown]
# Doc - https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.background_gradient.html

# %% [markdown]
# # 3. Rounding off `Time`

# %% [markdown]
# Display first five records

# %%
train.head()
# Out:
#    row_id                 time  x  y direction  congestion
# 0       0  1991-04-01 00:00:00  0  0        EB          70
# 1       1  1991-04-01 00:00:00  0  0        NB          49
# 2       2  1991-04-01 00:00:00  0  0        SB          24
# 3       3  1991-04-01 00:00:00  0  1        EB          18
# 4       4  1991-04-01 00:00:00  0  1        NB          60

# %%
train['time'] = pd.to_datetime(train['time']) # convert character into datetime object

# %%
train_dt = train.set_index('time') #DateTimeIndex

# %%
train_dt.index
# Out:
# DatetimeIndex(['1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                ...
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00'],
#               dtype='datetime64[ns]', name='time', length=848835, freq=None)

# %%
train_dt.index.round('S')
# Out:
# DatetimeIndex(['1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                ...
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00'],
#               dtype='datetime64[ns]', name='time', length=848835, freq=None)

# %% [markdown]
# # 3-10. In progress...

# %% [markdown]
# DateTimeIndex Offset alises - https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases

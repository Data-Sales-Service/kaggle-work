# %% [markdown]
# <a href="https://www.kaggle.com/code/muhammedtausif/10-simple-pandas-tricks-for-better-life?scriptVersionId=123564178" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <p style="background-color:red; font-size:70px; text-align:center; padding:30px; color: yellow; border-radius:30px">10 Simple 🐼 Pandas Tricks for better Life 👻</p>
#
# That's a bit of an exaggeration but these tips are very helpful in a lot of different cases.
# 1. ✅ Selecting a Type of Column
# 2. 🌈 DataFrame Formatting
# 3. 🔘 DateTime Rounding Off

# %% [markdown]
# importing pandas as pd, and os

# %%
import pandas as pd 
import os

# %%
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %% [markdown]
# Reading the data from *train.csv* file

# %%
train = pd.read_csv("/kaggle/input/tabular-playground-series-mar-2022/train.csv")

# %% [markdown]
# Printing the first **5** records with head() function

# %%
train.head()
# Out:
#    row_id                 time  x  y direction  congestion
# 0       0  1991-04-01 00:00:00  0  0        EB          70
# 1       1  1991-04-01 00:00:00  0  0        NB          49
# 2       2  1991-04-01 00:00:00  0  0        SB          24
# 3       3  1991-04-01 00:00:00  0  1        EB          18
# 4       4  1991-04-01 00:00:00  0  1        NB          60

# %% [markdown]
# Printing the last 5 records with head() function

# %%
train.tail()
# Out:
#         row_id                 time  x  y direction  congestion
# 848830  848830  1991-09-30 11:40:00  2  3        NB          54
# 848831  848831  1991-09-30 11:40:00  2  3        NE          28
# 848832  848832  1991-09-30 11:40:00  2  3        SB          68
# 848833  848833  1991-09-30 11:40:00  2  3        SW          17
# 848834  848834  1991-09-30 11:40:00  2  3        WB          24

# %% [markdown]
# # 1. Getting Numeric and Categorical Columns

# %% [markdown]
# Print the **data type** of the *colums*

# %%
train.dtypes
# Out:
# row_id         int64
# time          object
# x              int64
# y              int64
# direction     object
# congestion     int64
# dtype: object

# %% [markdown]
# Print the *columns* with data type **int64**

# %%
train.select_dtypes('int64')
# Out:
#         row_id  x  y  congestion
# 0            0  0  0          70
# 1            1  0  0          49
# 2            2  0  0          24
# 3            3  0  1          18
# 4            4  0  1          60
# ...        ... .. ..         ...
# 848830  848830  2  3          54
# 848831  848831  2  3          28
# 848832  848832  2  3          68
# 848833  848833  2  3          17
# 848834  848834  2  3          24
#
# [848835 rows x 4 columns]

# %% [markdown]
# Print the name of *columns* with type **object**

# %%
f"Categorical Columns {train.select_dtypes('object').columns.tolist()}"
# Out:
# "Categorical Columns ['time', 'direction']"

# %% [markdown]
# Print the name of *columns* with data type **int64**

# %%
f"Numeric Columns {train.select_dtypes('int64').columns.tolist()}"
# Out:
# "Numeric Columns ['row_id', 'x', 'y', 'congestion']"

# %% [markdown]
# Print the first five entries of the columns with data type **object**

# %%
train.select_dtypes('object').head()
# Out:
#                   time direction
# 0  1991-04-01 00:00:00        EB
# 1  1991-04-01 00:00:00        NB
# 2  1991-04-01 00:00:00        SB
# 3  1991-04-01 00:00:00        EB
# 4  1991-04-01 00:00:00        NB

# %% [markdown]
# Doc - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.select_dtypes.html

# %% [markdown]
# # 2. DataFrame Formatting

# %%
train.select_dtypes('int64').head(10).style.background_gradient(cmap='RdPu') #Pastel2 #YlOrRd #RdPu
# Out:
# <style type="text/css">
# #T_0c841_row0_col0, #T_0c841_row0_col1, #T_0c841_row0_col2, #T_0c841_row1_col1, #T_0c841_row1_col2, #T_0c841_row2_col1, #T_0c841_row2_col2, #T_0c841_row3_col1, #T_0c841_row3_col3, #T_0c841_row4_col1, #T_0c841_row5_col1, #T_0c841_row6_col1, #T_0c841_row7_col1, #T_0c841_row8_col1, #T_0c841_row9_col1 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_0c841_row0_col3, #T_0c841_row7_col2, #T_0c841_row8_col2, #T_0c841_row9_col0, #T_0c841_row9_col2 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_0c841_row1_col0 {
#   background-color: #fde3e0;
#   color: #000000;
# }
# #T_0c841_row1_col3, #T_0c841_row8_col3 {
#   background-color: #e34099;
#   color: #f1f1f1;
# }
# #T_0c841_row2_col0 {
#   background-color: #fcccc7;
#   color: #000000;
# }
# #T_0c841_row2_col3 {
#   background-color: #fde2df;
#   color: #000000;
# }
# #T_0c841_row3_col0 {
#   background-color: #fbacb9;
#   color: #000000;
# }
# #T_0c841_row3_col2, #T_0c841_row4_col2, #T_0c841_row5_col2, #T_0c841_row6_col2 {
#   background-color: #f767a1;
#   color: #f1f1f1;
# }
# #T_0c841_row4_col0 {
#   background-color: #f881aa;
#   color: #f1f1f1;
# }
# #T_0c841_row4_col3 {
#   background-color: #96017b;
#   color: #f1f1f1;
# }
# #T_0c841_row5_col0 {
#   background-color: #eb509c;
#   color: #f1f1f1;
# }
# #T_0c841_row5_col3 {
#   background-color: #a6017d;
#   color: #f1f1f1;
# }
# #T_0c841_row6_col0 {
#   background-color: #cd238f;
#   color: #f1f1f1;
# }
# #T_0c841_row6_col3 {
#   background-color: #fddad7;
#   color: #000000;
# }
# #T_0c841_row7_col0 {
#   background-color: #a1017c;
#   color: #f1f1f1;
# }
# #T_0c841_row7_col3 {
#   background-color: #fcc5c0;
#   color: #000000;
# }
# #T_0c841_row8_col0 {
#   background-color: #740175;
#   color: #f1f1f1;
# }
# #T_0c841_row9_col3 {
#   background-color: #ef599e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0c841_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >row_id</th>
#       <th class="col_heading level0 col1" >x</th>
#       <th class="col_heading level0 col2" >y</th>
#       <th class="col_heading level0 col3" >congestion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c841_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c841_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_0c841_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_0c841_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_0c841_row0_col3" class="data row0 col3" >70</td>
#     </tr>
#     <tr>
#       <th id="T_0c841_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c841_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_0c841_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_0c841_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_0c841_row1_col3" class="data row1 col3" >49</td>
#     </tr>
#     <tr>
#       <th id="T_0c841_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c841_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_0c841_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_0c841_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_0c841_row2_col3" class="data row2 col3" >24</td>
#     </tr>
#     <tr>
#       <th id="T_0c841_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0c841_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_0c841_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_0c841_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_0c841_row3_col3" class="data row3 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_0c841_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0c841_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_0c841_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_0c841_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_0c841_row4_col3" class="data row4 col3" >60</td>
#     </tr>
#     <tr>
#       <th id="T_0c841_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0c841_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_0c841_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_0c841_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_0c841_row5_col3" class="data row5 col3" >58</td>
#     </tr>
#     <tr>
#       <th id="T_0c841_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0c841_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_0c841_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_0c841_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_0c841_row6_col3" class="data row6 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_0c841_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0c841_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_0c841_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_0c841_row7_col2" class="data row7 col2" >2</td>
#       <td id="T_0c841_row7_col3" class="data row7 col3" >31</td>
#     </tr>
#     <tr>
#       <th id="T_0c841_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0c841_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_0c841_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_0c841_row8_col2" class="data row8 col2" >2</td>
#       <td id="T_0c841_row8_col3" class="data row8 col3" >49</td>
#     </tr>
#     <tr>
#       <th id="T_0c841_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0c841_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_0c841_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_0c841_row9_col2" class="data row9 col2" >2</td>
#       <td id="T_0c841_row9_col3" class="data row9 col3" >46</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #

# %% [markdown]
# Doc - https://pandas.pydata.org/docs/reference/api/pandas.io.formats.style.Styler.background_gradient.html

# %% [markdown]
# # 3. Rounding off `Time`

# %% [markdown]
# Display first five records

# %%
train.head()
# Out:
#    row_id                 time  x  y direction  congestion
# 0       0  1991-04-01 00:00:00  0  0        EB          70
# 1       1  1991-04-01 00:00:00  0  0        NB          49
# 2       2  1991-04-01 00:00:00  0  0        SB          24
# 3       3  1991-04-01 00:00:00  0  1        EB          18
# 4       4  1991-04-01 00:00:00  0  1        NB          60

# %%
train['time'] = pd.to_datetime(train['time']) # convert character into datetime object

# %%
train_dt = train.set_index('time') #DateTimeIndex

# %%
train_dt.index
# Out:
# DatetimeIndex(['1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                ...
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00'],
#               dtype='datetime64[ns]', name='time', length=848835, freq=None)

# %%
train_dt.index.round('S')
# Out:
# DatetimeIndex(['1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                '1991-04-01 00:00:00', '1991-04-01 00:00:00',
#                ...
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00',
#                '1991-09-30 11:40:00', '1991-09-30 11:40:00'],
#               dtype='datetime64[ns]', name='time', length=848835, freq=None)

# %% [markdown]
# # 3. Head and Tail

# %%
train.head()
# Out:
#    row_id       time  x  y direction  congestion
# 0       0 1991-04-01  0  0        EB          70
# 1       1 1991-04-01  0  0        NB          49
# 2       2 1991-04-01  0  0        SB          24
# 3       3 1991-04-01  0  1        EB          18
# 4       4 1991-04-01  0  1        NB          60

# %%
train.tail()
# Out:
#         row_id                time  x  y direction  congestion
# 848830  848830 1991-09-30 11:40:00  2  3        NB          54
# 848831  848831 1991-09-30 11:40:00  2  3        NE          28
# 848832  848832 1991-09-30 11:40:00  2  3        SB          68
# 848833  848833 1991-09-30 11:40:00  2  3        SW          17
# 848834  848834 1991-09-30 11:40:00  2  3        WB          24

# %%
# Selection of top 50 row
train.head(50)
# Out:
#     row_id       time  x  y direction  congestion
# 0        0 1991-04-01  0  0        EB          70
# 1        1 1991-04-01  0  0        NB          49
# 2        2 1991-04-01  0  0        SB          24
# 3        3 1991-04-01  0  1        EB          18
# 4        4 1991-04-01  0  1        NB          60
# 5        5 1991-04-01  0  1        SB          58
# 6        6 1991-04-01  0  1        WB          26
# 7        7 1991-04-01  0  2        EB          31
# 8        8 1991-04-01  0  2        NB          49
# 9        9 1991-04-01  0  2        SB          46
# 10      10 1991-04-01  0  2        WB          29
# 11      11 1991-04-01  0  3        EB          18
# 12      12 1991-04-01  0  3        NB          16
# 13      13 1991-04-01  0  3        NE          21
# 14      14 1991-04-01  0  3        SB          49
# 15      15 1991-04-01  0  3        SW          47
# 16      16 1991-04-01  0  3        WB          51
# 17      17 1991-04-01  1  0        EB          74
# 18      18 1991-04-01  1  0        NB          74
# 19      19 1991-04-01  1  0        NE          43
# 20      20 1991-04-01  1  0        SB          44
# 21      21 1991-04-01  1  0        SW          52
# 22      22 1991-04-01  1  0        WB          32
# 23      23 1991-04-01  1  1        EB          44
# 24      24 1991-04-01  1  1        NB          77
# 25      25 1991-04-01  1  1        SB          39
# 26      26 1991-04-01  1  1        WB          63
# 27      27 1991-04-01  1  2        EB          53
# 28      28 1991-04-01  1  2        NB          28
# 29      29 1991-04-01  1  2        NE          24
# 30      30 1991-04-01  1  2        SB          29
# 31      31 1991-04-01  1  2        SW          54
# 32      32 1991-04-01  1  2        WB          46
# 33      33 1991-04-01  1  3        EB          41
# 34      34 1991-04-01  1  3        NB          44
# 35      35 1991-04-01  1  3        NE          44
# 36      36 1991-04-01  1  3        SB          37
# 37      37 1991-04-01  1  3        SW          15
# 38      38 1991-04-01  1  3        WB          46
# 39      39 1991-04-01  2  0        EB          44
# 40      40 1991-04-01  2  0        NB          39
# 41      41 1991-04-01  2  0        SB          26
# 42      42 1991-04-01  2  0        WB          61
# 43      43 1991-04-01  2  1        EB          65
# 44      44 1991-04-01  2  1        NB          26
# 45      45 1991-04-01  2  1        NE          16
# 46      46 1991-04-01  2  1        NW          29
# 47      47 1991-04-01  2  1        SB          22
# 48      48 1991-04-01  2  1        SE          34
# 49      49 1991-04-01  2  1        SW          45

# %%
# Selection of last 50 rows of dataframe
train.tail(50)
# Out:
#         row_id                time  x  y direction  congestion
# 848785  848785 1991-09-30 11:40:00  0  3        SW          23
# 848786  848786 1991-09-30 11:40:00  0  3        WB          29
# 848787  848787 1991-09-30 11:40:00  1  0        EB          60
# 848788  848788 1991-09-30 11:40:00  1  0        NB          51
# 848789  848789 1991-09-30 11:40:00  1  0        NE          69
# 848790  848790 1991-09-30 11:40:00  1  0        SB          39
# 848791  848791 1991-09-30 11:40:00  1  0        SW          34
# 848792  848792 1991-09-30 11:40:00  1  0        WB          38
# 848793  848793 1991-09-30 11:40:00  1  1        EB          51
# 848794  848794 1991-09-30 11:40:00  1  1        NB          54
# 848795  848795 1991-09-30 11:40:00  1  1        SB          50
# 848796  848796 1991-09-30 11:40:00  1  1        WB          49
# 848797  848797 1991-09-30 11:40:00  1  2        EB          76
# 848798  848798 1991-09-30 11:40:00  1  2        NB          64
# 848799  848799 1991-09-30 11:40:00  1  2        NE          43
# 848800  848800 1991-09-30 11:40:00  1  2        SB          70
# 848801  848801 1991-09-30 11:40:00  1  2        SW          64
# 848802  848802 1991-09-30 11:40:00  1  2        WB          66
# 848803  848803 1991-09-30 11:40:00  1  3        EB          32
# 848804  848804 1991-09-30 11:40:00  1  3        NB          69
# 848805  848805 1991-09-30 11:40:00  1  3        NE          68
# 848806  848806 1991-09-30 11:40:00  1  3        SB          66
# 848807  848807 1991-09-30 11:40:00  1  3        SW          52
# 848808  848808 1991-09-30 11:40:00  1  3        WB          42
# 848809  848809 1991-09-30 11:40:00  2  0        EB          54
# 848810  848810 1991-09-30 11:40:00  2  0        NB          66
# 848811  848811 1991-09-30 11:40:00  2  0        SB          45
# 848812  848812 1991-09-30 11:40:00  2  0        WB          68
# 848813  848813 1991-09-30 11:40:00  2  1        EB          68
# 848814  848814 1991-09-30 11:40:00  2  1        NB          37
# 848815  848815 1991-09-30 11:40:00  2  1        NE          18
# 848816  848816 1991-09-30 11:40:00  2  1        NW          29
# 848817  848817 1991-09-30 11:40:00  2  1        SB          37
# 848818  848818 1991-09-30 11:40:00  2  1        SE          20
# 848819  848819 1991-09-30 11:40:00  2  1        SW          40
# 848820  848820 1991-09-30 11:40:00  2  1        WB          56
# 848821  848821 1991-09-30 11:40:00  2  2        EB          65
# 848822  848822 1991-09-30 11:40:00  2  2        NB          55
# 848823  848823 1991-09-30 11:40:00  2  2        NE          35
# 848824  848824 1991-09-30 11:40:00  2  2        NW          21
# 848825  848825 1991-09-30 11:40:00  2  2        SB          64
# 848826  848826 1991-09-30 11:40:00  2  2        SE          40
# 848827  848827 1991-09-30 11:40:00  2  2        SW          51
# 848828  848828 1991-09-30 11:40:00  2  2        WB          71
# 848829  848829 1991-09-30 11:40:00  2  3        EB          48
# 848830  848830 1991-09-30 11:40:00  2  3        NB          54
# 848831  848831 1991-09-30 11:40:00  2  3        NE          28
# 848832  848832 1991-09-30 11:40:00  2  3        SB          68
# 848833  848833 1991-09-30 11:40:00  2  3        SW          17
# 848834  848834 1991-09-30 11:40:00  2  3        WB          24

# %% [markdown]
# # 4. Meta Data of the DataFrame

# %%
# Shape of the data rowsxcolumn
train.shape
# Out:
# (848835, 6)

# %%
# Colunmns of the DataFrame
train.columns
# Out:
# Index(['row_id', 'time', 'x', 'y', 'direction', 'congestion'], dtype='object')

# %%
# Index description
train.index
# Out:
# RangeIndex(start=0, stop=848835, step=1)

# %%
# Info about dataframe
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 848835 entries, 0 to 848834
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   row_id      848835 non-null  int64
#  1   time        848835 non-null  datetime64[ns]
#  2   x           848835 non-null  int64
#  3   y           848835 non-null  int64
#  4   direction   848835 non-null  object
#  5   congestion  848835 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 38.9+ MB

# %%
# Describe statistics of the DataFrame
train.describe()
# Out:
#              row_id              x              y     congestion
# count  848835.00000  848835.000000  848835.000000  848835.000000
# mean   424417.00000       1.138462       1.630769      47.815305
# std    245037.70221       0.801478       1.089379      16.799392
# min         0.00000       0.000000       0.000000       0.000000
# 25%    212208.50000       0.000000       1.000000      35.000000
# 50%    424417.00000       1.000000       2.000000      47.000000
# 75%    636625.50000       2.000000       3.000000      60.000000
# max    848834.00000       2.000000       3.000000     100.000000

# %%
# Count 
train.count()
# Out:
# row_id        848835
# time          848835
# x             848835
# y             848835
# direction     848835
# congestion    848835
# dtype: int64

# %% [markdown]
# # 5-10. In progress...

# %% [markdown]
# DateTimeIndex Offset alises - https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases

# %% [markdown]
# <a href="https://www.kaggle.com/code/muhammedtausif/eda-tabular-playground-series-may-2022?scriptVersionId=117829709" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Tabular Playground Series - May 2022
# - **Goal:**
# 1. It is a binary classification problem
# 2. Target is to predict whether a machine is in state ` 0 or 1`
# - **Features:**
#
# | No | Variable | Value Type | Impact |
# |:---|:---|:---|:---|
# |1. |`f_27` | Charactor String of 10 Latters | |
# |2. |`f_00, 06, 19, 28`| Continues Numaric Values | |
# |3. |`f_07, 18, 29, 30`| Discrete whole number between [2-16] | |
# |4. | `target`| 0 or 1 | |

# %% [markdown]
# ### Importing libs

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/tabular-playground-series-may-2022/sample_submission.csv
# /kaggle/input/tabular-playground-series-may-2022/train.csv
# /kaggle/input/tabular-playground-series-may-2022/test.csv

# %% [markdown]
# ### Loading data

# %%
df = pd.read_csv('/kaggle/input/tabular-playground-series-may-2022/train.csv')

# %%
structure = df.shape

print('No of Rows: \t', structure[0])
print('No of Columns: \t', structure[1])
# Out:
# No of Rows: 	 900000
# No of Columns: 	 33

# %%
df.columns
# Out:
# Index(['id', 'f_00', 'f_01', 'f_02', 'f_03', 'f_04', 'f_05', 'f_06', 'f_07',
#        'f_08', 'f_09', 'f_10', 'f_11', 'f_12', 'f_13', 'f_14', 'f_15', 'f_16',
#        'f_17', 'f_18', 'f_19', 'f_20', 'f_21', 'f_22', 'f_23', 'f_24', 'f_25',
#        'f_26', 'f_27', 'f_28', 'f_29', 'f_30', 'target'],
#       dtype='object')

# %%
df_train = pd.read_csv('/kaggle/input/tabular-playground-series-may-2022/train.csv', index_col='id')

# %%
df_train.columns
# Out:
# Index(['f_00', 'f_01', 'f_02', 'f_03', 'f_04', 'f_05', 'f_06', 'f_07', 'f_08',
#        'f_09', 'f_10', 'f_11', 'f_12', 'f_13', 'f_14', 'f_15', 'f_16', 'f_17',
#        'f_18', 'f_19', 'f_20', 'f_21', 'f_22', 'f_23', 'f_24', 'f_25', 'f_26',
#        'f_27', 'f_28', 'f_29', 'f_30', 'target'],
#       dtype='object')

# %%
sns.set_theme()

# %%
df_train.f_00.head()
# Out:
# id
# 0   -1.373246
# 1    1.697021
# 2    1.681726
# 3   -0.118172
# 4    1.148481
# Name: f_00, dtype: float64

# %%
variables = ['f_00', 'f_01', 'f_02']
sns.pairplot(df_train, hue="target", vars=variables)

# %% [markdown]
# <a href="https://www.kaggle.com/code/muhammedtausif/kagglers-with-most-followers?scriptVersionId=103848910" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <div style='background-color:red;color:yellow;font-size:50px;text-align:center;padding:20px;'>Kagglers with most followers</div>
#
# Inspired from [this](https://www.kaggle.com/code/carlmcbrideellis/simple-eda-of-kaggle-grandmasters-scheduled) notebook. please acknowledge the original @carlmcbrideellis auther also.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime
pd.set_option('display.max_rows', None)
from IPython.display import Markdown

df_f = pd.read_csv('../input/meta-kaggle/UserFollowers.csv')
df_u = pd.read_csv('../input/meta-kaggle/Users.csv')

# %%
df_f.head(2)
# Out:
#    Id  UserId  FollowingUserId CreationDate
# 0   1   28963           611150   05/22/2017
# 1   4  304806              993   05/22/2017

# %%
df_u.head(2)
# Out:
#     Id      UserName        DisplayName RegisterDate  PerformanceTier
# 0    1    kaggleteam        Kaggle Team   03/24/2011                5
# 1  368  antgoldbloom  Anthony Goldbloom   01/20/2010                2

# %%
df = df_f.merge(df_u, on = 'Id')

# %%
df.head(5)
# Out:
#     Id   UserId  FollowingUserId CreationDate      UserName    DisplayName  \
# 0    1    28963           611150   05/22/2017    kaggleteam    Kaggle Team
# 1  381   255689           939660   05/25/2017        iguyon       Isabelle
# 2  383   424115           111640   05/25/2017  davidstephan  David Stephan
# 3  384   424115           149229   05/25/2017    gabewarren    Gabe Warren
# 4  385  1091691           505747   05/25/2017     demonjosh     Demon Josh
#
#   RegisterDate  PerformanceTier
# 0   03/24/2011                5
# 1   01/29/2010                2
# 2   02/01/2010                0
# 3   02/02/2010                0
# 4   02/02/2010                0

# %%
len(df.FollowingUserId.unique())
# Out:
# 149718

# %%
len(df.UserName.unique())
# Out:
# 898586

# %%
len(df.UserId.unique())
# Out:
# 299134

# %%
tf = df.groupby(['FollowingUserId']).size().sort_values(ascending=False).head(10)

# %%
# tf.UserName.map(lambda x: make_clickable_link(x))
tff = tf.to_frame()

# %%
tff.head()
# Out:
#                      0
# FollowingUserId
# 5309             15591
# 71388            12344
# 708283           11850
# 1723677          10904
# 54836             9551

# %%
tf
# Out:
# FollowingUserId
# 5309       15591
# 71388      12344
# 708283     11850
# 1723677    10904
# 54836       9551
# 4476084     9294
# 1014468     8804
# 1162990     8285
# 417337      7780
# 9028        7544
# dtype: int64

# %%
df.groupby('UserName').size().sort_values(ascending=True).head(10)
# Out:
# UserName
# Amateurscience       1
# peterfishman         1
# peterflom            1
# peterfong            1
# peterfong1           1
# peterforbes          1
# peterford            1
# peterfoster1         1
# peterfotheringham    1
# peterfowles          1
# dtype: int64

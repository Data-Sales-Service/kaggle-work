# %% [markdown]
# <a href="https://www.kaggle.com/code/muhammedtausif/shar-tank-india-eda?scriptVersionId=107081213" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <div style="background-color: red; text-align:center; color:yellow; padding:60px; font-size:50px">Shar Tank India: EDA</div>
#
# In this notebook, the data from the shark tank india will be analyzed.

# %% [markdown]
# ## Acknowledgement
# This is copy of the [orignal](https://www.kaggle.com/rahulphatak/shark-tank-data-analysis) work, for the purpose to learning and practice. Please credit the orignal auther at this [link](https://www.kaggle.com/rahulphatak/shark-tank-data-analysis)

# %% [markdown]
# ## Setup the Environment
# In the following code block the environmnet for the analysis would be set.
# ### Imports
# Following liberaries are imported
# 1. Numpy
# 2. Pandas
# 3. os
# 4. searborn
# 5. matplotlib

# %% [markdown]
# numpy as *np*,
# pandas as *pd*,
# matplotlib.pyplot as *plt*,
# seaborn as *sns*

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read the "*Shark Tank India Dataset.csv*" with help of **read_csv** function of **panda**. And then save the result into a dataframe called "*df*".
#
# <div style='color:blue'>Adding new dataset <b>df_sk_n</b>. The EDA of df_sk_n is in progress</div>

# %%
df = pd.read_csv('../input/shark-tank-india-dataset/Shark Tank India Dataset.csv')

df_sk_n = pd.read_csv('../input/sharktankindia/ShartankIndiaAllPitches.csv')

# %% [markdown]
# Display the head of the data with **head()** function of **dataframe**.

# %%
df.head()
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0        16.00  ...             1
# ...

# %%
df_sk_n.head()
# Out:
#    Episode Number  Pitch Number                Brand  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             Idea  \
# 0                                   Frozen Momos
# 1  Renting e-bike for mobility in private spaces
# 2                             Detachable Sleeves
# 3                           Healthy Potato Chips
# 4                       Brain Development Course
#
#    Investment Amount (In Lakhs INR)   Debt (In lakhs INR) Equity Anupam  \
# 0                                 75                    0    18%      N
# 1                                 40                    0    50%      N
# 2                                 25                    0    30%      Y
# ...

# %% [markdown]
# Display the number of columns and rows with **shape** function of **dataframe**.

# %%
df.shape
# Out:
# (117, 28)

# %%
df_sk_n.shape
# Out:
# (117, 15)

# %% [markdown]
# Use **describe** function of the DataFrame to display the *count, mean, std, min, 25%, 75%, and max*.

# %%
df.describe()
# Out:
#        episode_number  pitch_number        deal  pitcher_ask_amount  \
# count      117.000000    117.000000  117.000000          117.000000
# mean        18.735043     59.000000    0.555556          319.854709
# std         10.070778     33.919021    0.499041         2767.842777
# min          1.000000      1.000000    0.000000            0.001010
# 25%         10.000000     30.000000    0.000000           45.000000
# 50%         19.000000     59.000000    1.000000           50.000000
# 75%         27.000000     88.000000    1.000000           80.000000
# max         35.000000    117.000000    1.000000        30000.000000
#
#        ask_equity  ask_valuation  deal_amount  deal_equity  deal_valuation  \
# count  117.000000     117.000000   117.000000   117.000000      117.000000
# mean     5.188034    3852.462479    31.982915     8.963504      467.104872
# std      3.892121   11931.601957    36.687391    13.106769      919.988864
# ...

# %%
df_sk_n.describe()
# Out:
#        Episode Number  Pitch Number  Investment Amount (In Lakhs INR)   \
# count      117.000000    117.000000                         117.000000
# mean        18.735043     59.000000                          21.683761
# std         10.070778     33.919021                          26.067766
# min          1.000000      1.000000                           0.000000
# 25%         10.000000     30.000000                           0.000000
# 50%         19.000000     59.000000                          10.000000
# 75%         27.000000     88.000000                          50.000000
# max         35.000000    117.000000                          80.000000
#
#        Debt (In lakhs INR)  Season
# count           117.000000   117.0
# mean              2.572650     1.0
# std              11.544753     0.0
# min               0.000000     1.0
# 25%               0.000000     1.0
# 50%               0.000000     1.0
# 75%               0.000000     1.0
# max              99.000000     1.0

# %% [markdown]
# Use **info** function of the Dataframe to display *detail of columns* of the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %% [markdown]
# According to data company doesn't recieve an offer so not a deal where reject offer is equals na. Therefore we can make that offer to reject offer

# %%
df.isna().any()
# Out:
# episode_number           False
# pitch_number             False
# brand_name               False
# idea                     False
# deal                     False
# pitcher_ask_amount       False
# ask_equity               False
# ask_valuation            False
# deal_amount              False
# deal_equity              False
# deal_valuation           False
# ashneer_present          False
# anupam_present           False
# aman_present             False
# namita_present           False
# vineeta_present          False
# peyush_present           False
# ghazal_present           False
# ashneer_deal             False
# anupam_deal              False
# aman_deal                False
# namita_deal              False
# vineeta_deal             False
# peyush_deal              False
# ghazal_deal              False
# total_sharks_invested    False
# amount_per_shark         False
# equity_per_shark         False
# dtype: bool

# %% [markdown]
# Display columns

# %%
df.columns
# Out:
# Index(['episode_number', 'pitch_number', 'brand_name', 'idea', 'deal',
#        'pitcher_ask_amount', 'ask_equity', 'ask_valuation', 'deal_amount',
#        'deal_equity', 'deal_valuation', 'ashneer_present', 'anupam_present',
#        'aman_present', 'namita_present', 'vineeta_present', 'peyush_present',
#        'ghazal_present', 'ashneer_deal', 'anupam_deal', 'aman_deal',
#        'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal',
#        'total_sharks_invested', 'amount_per_shark', 'equity_per_shark'],
#       dtype='object')

# %%
df['deal'].value_counts()
# Out:
# 1    65
# 0    52
# Name: deal, dtype: int64

# %%
df[df['pitcher_ask_amount']==df['pitcher_ask_amount'].max()]
# Out:
#     episode_number  pitch_number  brand_name             idea  deal  \
# 30              11            31  Gopal's 56  Fiber Ice Cream     0
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 30             30000.0        25.0       120000.0          0.0          0.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 30  ...             0            0          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 30            0            0                      0               0.0
#
#     equity_per_shark
# 30               0.0
#
# [1 rows x 28 columns]

# %%
df[df['deal_amount']==df['deal_amount'].max()]
# Out:
#     episode_number  pitch_number     brand_name        idea  deal  \
# 50              17            51  Aas Vidyalaya  EdTech App     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 50               150.0         3.0         5000.0        150.0         15.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 50  ...             1            0          0            1             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 50            1            0                      3              50.0
#
#     equity_per_shark
# 50               5.0
#
# [1 rows x 28 columns]

# %%
df[df['ask_valuation']==df['ask_valuation'].max()]
# Out:
#     episode_number  pitch_number  brand_name             idea  deal  \
# 30              11            31  Gopal's 56  Fiber Ice Cream     0
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 30             30000.0        25.0       120000.0          0.0          0.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 30  ...             0            0          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 30            0            0                      0               0.0
#
#     equity_per_shark
# 30               0.0
#
# [1 rows x 28 columns]

# %%
df[df['ask_equity']==df['ask_equity'].min()]
# Out:
#    episode_number  pitch_number   brand_name                     idea  deal  \
# 6               3             7  Qzense Labs  Food Freshness Detector     0
#
#    pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 6               100.0        0.25        40000.0          0.0          0.0
#
#    ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 6  ...             0            0          0            0             0
#
#    peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 6            0            0                      0               0.0
#
#    equity_per_shark
# 6               0.0
#
# [1 rows x 28 columns]

# %%
df[df['deal_valuation']==df['deal_valuation'].max()]
# Out:
#     episode_number  pitch_number   brand_name    idea  deal  \
# 12               5            13  Revamp Moto  E-Bike     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 12               100.0         1.0        10000.0        100.0          1.5
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 12  ...             0            1          1            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 12            0            0                      2              50.0
#
#     equity_per_shark
# 12              0.75
#
# [1 rows x 28 columns]

# %%
def synergy(data):
  list = ['anupam_deal','aman_deal','namita_deal','vineeta_deal','peyush_deal','ghazal_deal','ashneer_deal']
  for i in list:
    deal = data[['amount_per_shark','equity_per_shark']][data[i]==1]
    print("\n{} deals with {}".format(len(deal),i[:-5]))
    print(deal)

# %%
ash_grover = df[df['ashneer_deal']==1]
ash_grover
# Out:
#      episode_number  pitch_number             brand_name  \
# 0                 1             1    BluePine Industries
# 1                 1             2          Booz scooters
# 3                 2             4             Tagz Foods
# 15                6            16            Skippi Pops
# 18                7            19     Raising Superstars
# 21                8            22           Beyond Snack
# 23                8            24          Motion Breeze
# 29               10            30              EventBeep
# 38               13            39        The Yarn Bazaar
# 45               16            46           Bamboo India
# 49               17            50  Find Your Kicks India
# 50               17            51          Aas Vidyalaya
# 55               18            56                   Otua
# 58               19            59                WeSTOCK
# 63               20            64               IN A CAN
# ...

# %%
ash_grover['amount_per_shark'].sum()
# Out:
# 494.33333333

# %%
synergy(ash_grover)
# Out:
# 8 deals with anupam
#      amount_per_shark  equity_per_shark
# 15               20.0          3.000000
# 38               25.0          2.500000
# 45               25.0          1.750000
# 49               10.0          5.000000
# 63               20.0          2.000000
# 67               20.0          1.333333
# 108              20.0          3.333333
# 114              10.0          7.500000
#
# 11 deals with aman
#      amount_per_shark  equity_per_shark
# 0           25.000000          5.333333
# 15          20.000000          3.000000
# 18          50.000000          2.000000
# 21          25.000000          1.250000
# 29          10.000000          1.000000
# 38          25.000000          2.500000
# 49          10.000000          5.000000
# 58          15.000000          2.500000
# 63          20.000000          2.000000
# 64          33.333333          5.000000
# 114         10.000000          7.500000
#
# 6 deals with namita
#      amount_per_shark  equity_per_shark
# ...

# %%
am_gupta = df[df['aman_deal']==1]

# %%
synergy(am_gupta)
# Out:
# 10 deals with anupam
#      amount_per_shark  equity_per_shark
# 12          50.000000          0.750000
# 15          20.000000          3.000000
# 28          10.000000          6.666667
# 35          13.333333          8.000000
# 38          25.000000          2.500000
# 44           0.000017          1.666667
# 48          22.500000          6.000000
# 49          10.000000          5.000000
# 63          20.000000          2.000000
# 114         10.000000          7.500000
#
# 28 deals with aman
#      amount_per_shark  equity_per_shark
# 0           25.000000          5.333333
# 7           75.000000          6.000000
# 11          37.500000          3.750000
# 12          50.000000          0.750000
# 15          20.000000          3.000000
# 18          50.000000          2.000000
# 21          25.000000          1.250000
# 24          25.000000          3.500000
# 25          25.000000          5.000000
# 27           8.333333          6.666667
# ...

# %%
eqt = df.groupby('ashneer_deal')['equity_per_shark'].sum().loc[1]
amt = df.groupby('ashneer_deal')['amount_per_shark'].sum().loc[1]
print("Total equity buy on shark tank",eqt,'%')
print("Total amount invested on shark tank",amt,"lakhs")
# Out:
# Total equity buy on shark tank 93.249999999 %
# Total amount invested on shark tank 494.33333333 lakhs

# %%
ash_grover[ash_grover['amount_per_shark']==ash_grover['amount_per_shark'].max()]
# Out:
#    episode_number  pitch_number  brand_name                  idea  deal  \
# 3               2             4  Tagz Foods  Healthy Potato Chips     1
#
#    pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 3                70.0         1.0         7000.0         70.0         2.75
#
#    ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 3  ...             1            0          0            0             0
#
#    peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 3            0            0                      1              70.0
#
#    equity_per_shark
# 3              2.75
#
# [1 rows x 28 columns]

# %%
ash_grover[ash_grover['equity_per_shark']==ash_grover['equity_per_shark'].max()]
# Out:
#    episode_number  pitch_number     brand_name  \
# 1               1             2  Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 1            0                      2              20.0              25.0
#
# [1 rows x 28 columns]

# %%
df['ashneer_deal'].sum()
# Out:
# 21

# %% [markdown]
# I am doing analysis only of ashneer you can try all others.

# %%
list = ['anupam_present','aman_present','namita_present','vineeta_present','peyush_present','ghazal_present','ashneer_present']
for i in list:
    pres = df[i].sum()
    print(i[:-8],"present in front of",pres,"companies" )
# Out:
# anupam present in front of 117 companies
# aman present in front of 98 companies
# namita present in front of 106 companies
# vineeta present in front of 66 companies
# peyush present in front of 88 companies
# ghazal present in front of 26 companies
# ashneer present in front of 98 companies

# %%
list = ['anupam_deal','aman_deal','namita_deal','vineeta_deal','peyush_deal','ghazal_deal','ashneer_deal']
for i in list:
    deal = df[i].sum()
    print(i[:-5],"deals with",deal,"companies" )
# Out:
# anupam deals with 24 companies
# aman deals with 28 companies
# namita deals with 22 companies
# vineeta deals with 15 companies
# peyush deals with 27 companies
# ghazal deals with 7 companies
# ashneer deals with 21 companies

# %% [markdown]
# **All Shark Deal**

# %%
all_shark = df[df['total_sharks_invested']>=5]
all_shark
# Out:
#     episode_number  pitch_number             brand_name                 idea  \
# 15               6            16            Skippi Pops             Ice-Pops
# 49              17            50  Find Your Kicks India       Sneaker Resale
# 63              20            64               IN A CAN        Can Cocktails
# 79              25            80    Sunfox Technologies  Portable ECG Device
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 15     1                45.0         5.0          900.0        100.0
# 49     1                50.0        10.0          500.0         50.0
# 63     1                50.0         2.0         2500.0        100.0
# 79     1               100.0         2.0         5000.0        100.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# 15         15.0  ...             1            1          1            1
# 49         25.0  ...             1            1          1            1
# ...

# %%
deals_5 = df.sort_values('deal_amount',ascending=False)
deals_5.head()
# Out:
#     episode_number  pitch_number         brand_name                     idea  \
# 50              17            51      Aas Vidyalaya               EdTech App
# 36              13            37              Annie  Braille Literary Device
# 12               5            13        Revamp Moto                   E-Bike
# 38              13            39    The Yarn Bazaar         Yarn-Trading App
# 39              14            40  The Renal Project  Home Dialysis Treatment
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 50     1               150.0         3.0        5000.00        150.0
# 36     1                30.0         5.0         600.00        105.0
# 12     1               100.0         1.0       10000.00        100.0
# 38     1                50.0         2.0        2500.00        100.0
# 39     1               100.0         3.0        3333.33        100.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# ...

# %%
deals_5_eq = df.sort_values('deal_equity',ascending=False)
deals_5_eq.head()
# Out:
#     episode_number  pitch_number        brand_name  \
# 65              21            66     Sid07 Designs
# 81              26            82   Isak Fragrances
# 1                1             2     Booz scooters
# 42              15            43  Hammer Lifestyle
# 76              24            77       KG Agrotech
#
#                                              idea  deal  pitcher_ask_amount  \
# 65                                     Inventions     1                47.0
# 81                                       Perfumes     1                50.0
# 1   Renting e-bike for mobility in private spaces     1                40.0
# 42                           Smart Audio Products     1                30.0
# 76                       Agricultural Innovations     1                30.0
#
#     ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 65        10.0         470.00         25.0         75.0  ...             0
# ...

# %%
deals_5_valu = df.sort_values('deal_valuation',ascending=False)
deals_5_valu.head()
# Out:
#      episode_number  pitch_number   brand_name                     idea  deal  \
# 12                5            13  Revamp Moto                   E-Bike     1
# 36               13            37        Annie  Braille Literary Device     1
# 100              31           101     AyuRythm   Ayurvedic Wellness App     1
# 3                 2             4   Tagz Foods     Healthy Potato Chips     1
# 104              32           105   GrowFitter              Rewards App     1
#
#      pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 12                100.0         1.0        10000.0        100.0         1.50
# 36                 30.0         5.0          600.0        105.0         3.00
# 100                75.0         2.0         3750.0         75.0         2.68
# 3                  70.0         1.0         7000.0         70.0         2.75
# 104                50.0         1.0         5000.0         50.0         2.00
#
# ...

# %% [markdown]
#  **NON BARGAIN DEAL**

# %%
df[df['ask_valuation']==df['deal_valuation']]
# Out:
#     episode_number  pitch_number    brand_name                 idea  deal  \
# 21               8            22  Beyond Snack  Kerala Banana Chips     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 21                50.0         2.5         2000.0         50.0          2.5
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 21  ...             1            0          1            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 21            0            0                      2              25.0
#
#     equity_per_shark
# 21              1.25
#
# [1 rows x 28 columns]

# %%
sns.countplot(x='total_sharks_invested',data=df)
# Out:
# <AxesSubplot:xlabel='total_sharks_invested', ylabel='count'>

# %% [markdown]
# # The End

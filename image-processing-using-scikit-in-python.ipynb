# %% [markdown]
# <a href="https://www.kaggle.com/code/muhammedtausif/image-processing-using-scikit-in-python?scriptVersionId=117737843" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# Import skimage, and io

# %%
import skimage
from skimage import io

# %%
img = io.imread( '/kaggle/input/rose-flowers/Yellow Rose New (1).jpg')

# %%
io.imshow(img)

# %% [markdown]
# Working on.

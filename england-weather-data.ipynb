# %% [markdown]
# <a href="https://www.kaggle.com/code/muhammedtausif/england-weather-data?scriptVersionId=123508059" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # England Weather Data
# This notebook is copied for learning purposes only, please credit the original auther as described in below line.
# ### You can contact me by email : mahsaghonchehei18@gmail.com

# %% [markdown]
# Importing Numpy, Pandas, and MatPlotLib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Reading Data EnglandWeather.csv

# %%
data = pd.read_csv("/kaggle/input/englandweather/EnglandWeather.csv")
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-01-01 00:00:00.000 +0100  Partly Cloudy        rain
# 1      2006-01-01 01:00:00.000 +0100  Mostly Cloudy        rain
# 2      2006-01-01 02:00:00.000 +0100  Mostly Cloudy        rain
# 3      2006-01-01 03:00:00.000 +0100       Overcast        rain
# 4      2006-01-01 04:00:00.000 +0100  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-12-31 19:00:00.000 +0100  Mostly Cloudy        rain
# 96449  2016-12-31 20:00:00.000 +0100  Mostly Cloudy        rain
# 96450  2016-12-31 21:00:00.000 +0100  Mostly Cloudy        snow
# 96451  2016-12-31 22:00:00.000 +0100  Mostly Cloudy        snow
# 96452  2016-12-31 23:00:00.000 +0100  Mostly Cloudy        snow
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             0.577778            17.1143               1016.66      0.89
# ...

# %% [markdown]
# Converting the CSV file to Pandas DataFrame (Even though this step was not required).

# %%
df = pd.DataFrame(data)
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-01-01 00:00:00.000 +0100  Partly Cloudy        rain
# 1      2006-01-01 01:00:00.000 +0100  Mostly Cloudy        rain
# 2      2006-01-01 02:00:00.000 +0100  Mostly Cloudy        rain
# 3      2006-01-01 03:00:00.000 +0100       Overcast        rain
# 4      2006-01-01 04:00:00.000 +0100  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-12-31 19:00:00.000 +0100  Mostly Cloudy        rain
# 96449  2016-12-31 20:00:00.000 +0100  Mostly Cloudy        rain
# 96450  2016-12-31 21:00:00.000 +0100  Mostly Cloudy        snow
# 96451  2016-12-31 22:00:00.000 +0100  Mostly Cloudy        snow
# 96452  2016-12-31 23:00:00.000 +0100  Mostly Cloudy        snow
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             0.577778            17.1143               1016.66      0.89
# ...

# %% [markdown]
# Describing the weather data.

# %%
df.describe()
# Out:
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)      Humidity
# count     96453.000000       96453.000000          96453.000000  96453.000000
# mean         11.932678          10.810640           1003.235956      0.734899
# std           9.551546           6.913571            116.969906      0.195473
# min         -21.822222           0.000000              0.000000      0.000000
# 25%           4.688889           5.828200           1011.900000      0.600000
# 50%          12.000000           9.965900           1016.450000      0.780000
# 75%          18.838889          14.135800           1021.090000      0.890000
# max          39.905556          63.852600           1046.380000      1.000000

# %%
df[["Formatted Date","Humidity"]]
# Out:
#                       Formatted Date  Humidity
# 0      2006-01-01 00:00:00.000 +0100      0.89
# 1      2006-01-01 01:00:00.000 +0100      0.85
# 2      2006-01-01 02:00:00.000 +0100      0.82
# 3      2006-01-01 03:00:00.000 +0100      0.82
# 4      2006-01-01 04:00:00.000 +0100      0.86
# ...                              ...       ...
# 96448  2016-12-31 19:00:00.000 +0100      0.86
# 96449  2016-12-31 20:00:00.000 +0100      0.88
# 96450  2016-12-31 21:00:00.000 +0100      0.89
# 96451  2016-12-31 22:00:00.000 +0100      0.91
# 96452  2016-12-31 23:00:00.000 +0100      0.92
#
# [96453 rows x 2 columns]

# %% [markdown]
# Getting the date only from the complete formated date. It means that the timezone, and time in form of hours, minutes, seconds and miliseconds are truncated.
# **This is done by spling the str by space**
#
# After that formated date will only contains that date.

# %%
df["Formatted Date"] = df["Formatted Date"].str.split(' ', expand = True)[0]
df
# Out:
#       Formatted Date        Summary Precip Type  Temperature (C)  \
# 0         2006-01-01  Partly Cloudy        rain         0.577778
# 1         2006-01-01  Mostly Cloudy        rain         1.161111
# 2         2006-01-01  Mostly Cloudy        rain         1.666667
# 3         2006-01-01       Overcast        rain         1.711111
# 4         2006-01-01  Mostly Cloudy        rain         1.183333
# ...              ...            ...         ...              ...
# 96448     2016-12-31  Mostly Cloudy        rain         0.488889
# 96449     2016-12-31  Mostly Cloudy        rain         0.072222
# 96450     2016-12-31  Mostly Cloudy        snow        -0.233333
# 96451     2016-12-31  Mostly Cloudy        snow        -0.472222
# 96452     2016-12-31  Mostly Cloudy        snow        -0.677778
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0                17.1143               1016.66      0.89
# 1                16.6152               1016.15      0.85
# ...

# %% [markdown]
# Dropping the null entries from the Dataframe, and making a copy in variable **df1**.

# %%
df1 = df.dropna()
df1
# Out:
#       Formatted Date        Summary Precip Type  Temperature (C)  \
# 0         2006-01-01  Partly Cloudy        rain         0.577778
# 1         2006-01-01  Mostly Cloudy        rain         1.161111
# 2         2006-01-01  Mostly Cloudy        rain         1.666667
# 3         2006-01-01       Overcast        rain         1.711111
# 4         2006-01-01  Mostly Cloudy        rain         1.183333
# ...              ...            ...         ...              ...
# 96448     2016-12-31  Mostly Cloudy        rain         0.488889
# 96449     2016-12-31  Mostly Cloudy        rain         0.072222
# 96450     2016-12-31  Mostly Cloudy        snow        -0.233333
# 96451     2016-12-31  Mostly Cloudy        snow        -0.472222
# 96452     2016-12-31  Mostly Cloudy        snow        -0.677778
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0                17.1143               1016.66      0.89
# 1                16.6152               1016.15      0.85
# ...

# %% [markdown]
# Sort the values by **Humidity**, and creating a copy of **df1** to **df2**.

# %%
df2 = df1.sort_values(by=["Humidity"])
df2[["Summary","Humidity"]].tail(20)
# Out:
#              Summary  Humidity
# 60515          Foggy       1.0
# 60514          Foggy       1.0
# 60513          Foggy       1.0
# 60512          Foggy       1.0
# 60511          Foggy       1.0
# 63425          Foggy       1.0
# 60523  Mostly Cloudy       1.0
# 60510          Foggy       1.0
# 60508          Foggy       1.0
# 63429       Overcast       1.0
# 63430       Overcast       1.0
# 63431       Overcast       1.0
# 63432       Overcast       1.0
# 4901           Clear       1.0
# 60507          Foggy       1.0
# 91440  Mostly Cloudy       1.0
# 91439  Mostly Cloudy       1.0
# 63434          Foggy       1.0
# 60509          Foggy       1.0
# 44277       Overcast       1.0

# %%
df2["Summary"].unique()
# Out:
# array(['Foggy', 'Overcast', 'Mostly Cloudy', 'Partly Cloudy', 'Clear',
#        'Dry and Partly Cloudy', 'Dry', 'Breezy and Mostly Cloudy',
#        'Breezy and Overcast', 'Dry and Mostly Cloudy',
#        'Breezy and Partly Cloudy', 'Breezy', 'Windy and Overcast',
#        'Windy and Dry', 'Breezy and Dry', 'Windy and Partly Cloudy',
#        'Windy and Mostly Cloudy', 'Windy',
#        'Dangerously Windy and Partly Cloudy', 'Drizzle', 'Light Rain',
#        'Windy and Foggy', 'Humid and Partly Cloudy',
#        'Humid and Mostly Cloudy', 'Breezy and Foggy',
#        'Humid and Overcast', 'Rain'], dtype=object)

# %%
df2.groupby(["Summary"]).mean()
# Out:
#                                      Temperature (C)  Wind Speed (km/h)  \
# Summary
# Breezy                                      7.922016          32.143948
# Breezy and Dry                             21.111111          33.810000
# Breezy and Foggy                           -0.510317          33.477880
# Breezy and Mostly Cloudy                   11.093411          33.386345
# Breezy and Overcast                         7.241614          33.037566
# Breezy and Partly Cloudy                   12.492761          33.532796
# Clear                                      11.976203           8.127655
# Dangerously Windy and Partly Cloudy         8.944444          63.852600
# Drizzle                                    10.847578          10.356428
# Dry                                        29.083660          14.713979
# Dry and Mostly Cloudy                      26.838492          13.667750
# Dry and Partly Cloudy                      26.605749          12.304519
# ...

# %%
df2.groupby(["Summary"]).mean()["Humidity"]
# Out:
# Summary
# Breezy                                 0.637778
# Breezy and Dry                         0.260000
# Breezy and Foggy                       0.938571
# Breezy and Mostly Cloudy               0.637054
# Breezy and Overcast                    0.763144
# Breezy and Partly Cloudy               0.545803
# Clear                                  0.729231
# Dangerously Windy and Partly Cloudy    0.490000
# Drizzle                                0.867949
# Dry                                    0.230294
# Dry and Mostly Cloudy                  0.242143
# Dry and Partly Cloudy                  0.240814
# Foggy                                  0.950916
# Humid and Mostly Cloudy                0.874250
# Humid and Overcast                     0.881429
# Humid and Partly Cloudy                0.848824
# Light Rain                             0.888095
# Mostly Cloudy                          0.725162
# Overcast                               0.837610
# ...

# %% [markdown]
# Creating a plot:
# 1. Creating a figure of size 15x10, with 80 dpi
# 2. Creating a Scatter graph between **Summary** and **Humidity**, and setting the color to **red**, with alpha as 0.5
# 3. Setting **xlabel** to **Summary**, **ylabel** to **Humidity**, title as **Humidity By Summary**. The xlabel, and ylabel are size of 20px, while the title has 25px size.
# 4. Set xticks to 15px, and rotate it to **90 degree**, as the labels are lengthy, and set the ylabel to 15 pixal.
# 5. Make the plot as **Grid**, and display graph with **show**.

# %%
plt.figure(figsize = (15,10), dpi = 80)
plt.scatter(df2["Summary"], df2["Humidity"], color = ["red"],alpha = 0.5 )
plt.xlabel("\nSummary", fontsize = 20)
plt.ylabel("\nHumidity\n", fontsize = 20)
plt.title("Humidity By Summary\n", fontsize = 25)
plt.xticks(fontsize = 15 , rotation = 90)
plt.yticks(fontsize = 15)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Will Resume from here...

# %%
plt.figure(figsize = (15,10), dpi = 80)
plt.scatter(df2["Humidity"], df2["Temperature (C)"], color = ["darkcyan"],alpha = 0.5 )
plt.xlabel("\nTemperature", fontsize = 20)
plt.ylabel("\nHumidity\n", fontsize = 20)
plt.title("Humidity By Temperature \n", fontsize = 20)
plt.xticks(fontsize = 15 , rotation = 90)
plt.yticks(fontsize = 15)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (15,10), dpi = 80)
plt.scatter(df2["Humidity"], df2["Wind Speed (km/h)"], color = ["darkgoldenrod"],alpha = 0.5 )
plt.xlabel("\nWind Speed", fontsize = 20)
plt.ylabel("\nHumidity\n", fontsize = 20)
plt.title("Humidity By Wind Speed \n", fontsize = 20)
plt.xticks(fontsize = 15 , rotation = 90)
plt.yticks(fontsize = 15)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (15,10), dpi = 80)
plt.scatter(df2["Humidity"], df2["Pressure (millibars)"], color = ["darkred"], alpha = 0.5 )
plt.xlabel("\nPressure", fontsize = 20)
plt.ylabel("\nHumidity\n", fontsize = 20)
plt.title("Humidity By Pressure \n", fontsize = 20)
plt.xticks(fontsize = 15 , rotation = 90)
plt.yticks(fontsize = 15)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (15,8), dpi = 80)
plt.scatter(df1["Precip Type"], df1["Humidity"], color = ["darksalmon"], alpha = 0.5 )
plt.xlabel("\nWeather Type", fontsize = 20)
plt.ylabel("\nHumidity\n", fontsize = 20)
plt.title("Humidity By Weather Type \n", fontsize = 20)
plt.xticks(fontsize = 15 , rotation = 90)
plt.yticks(fontsize = 15)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #

# %%
year = pd.to_datetime(df1["Formatted Date"]).dt.year

# %%
df1["Formatted Date"] = year
df1
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Formatted Date        Summary Precip Type  Temperature (C)  \
# 0                2006  Partly Cloudy        rain         0.577778
# 1                2006  Mostly Cloudy        rain         1.161111
# 2                2006  Mostly Cloudy        rain         1.666667
# 3                2006       Overcast        rain         1.711111
# 4                2006  Mostly Cloudy        rain         1.183333
# ...               ...            ...         ...              ...
# 96448            2016  Mostly Cloudy        rain         0.488889
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize = (15,8), dpi = 80)
sns.countplot(x = year, )
plt.title("Count Year \n", fontsize = 20)
plt.xlabel("\nYears", fontsize = 20)
plt.ylabel("\nCount\n", fontsize = 20)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (15,8), dpi = 80)
plt.scatter(df1["Formatted Date"], df1["Humidity"], color = ["gold"], alpha = 0.5)
plt.xlabel("\nDate", fontsize = 20)
plt.ylabel("\nHumidity\n", fontsize = 20)
plt.title("Humidity By Date \n", fontsize = 20)
plt.xticks(fontsize = 15 , rotation = 90)
plt.yticks(fontsize = 15)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (15,8), dpi = 80)
plt.scatter(df1["Formatted Date"], df1["Temperature (C)"], color = ["gold"], alpha = 0.5)
plt.xlabel("\nDate", fontsize = 20)
plt.ylabel("\nHumidity\n", fontsize = 20)
plt.title("Humidity By Date \n", fontsize = 20)
plt.xticks(fontsize = 15 , rotation = 90)
plt.yticks(fontsize = 15)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize = (15,8), dpi = 80)
plt.scatter(df1["Formatted Date"], df1["Wind Speed (km/h)"], color = ["gold"], alpha = 0.5)
plt.xlabel("\nDate", fontsize = 20)
plt.ylabel("\nHumidity\n", fontsize = 20)
plt.title("Humidity By Date \n", fontsize = 20)
plt.xticks(fontsize = 15 , rotation = 90)
plt.yticks(fontsize = 15)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### You can contact me by email : mahsaghonchehei18@gmail.com

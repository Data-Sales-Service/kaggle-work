# %% [markdown]
# <a href="https://www.kaggle.com/code/muhammedtausif/jpx-tokyo-stock-exchange-eda?scriptVersionId=118000561" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/stock_list.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/sample_submission.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/options.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/financials.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/secondary_stock_prices.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/trades.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/stock_prices.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/jpx_tokyo_market_prediction/competition.cpython-37m-x86_64-linux-gnu.so
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/jpx_tokyo_market_prediction/__init__.py
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/data_specifications/stock_fin_spec.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/data_specifications/trades_spec.csv
# ...

# %%
paths_dictionary = {}
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        paths_dictionary[filename.split('.')[0]] = os.path.join(dirname, filename)

# %%
from IPython.display import display, Markdown, Latex

# %%
table = '''| Name | Path |
|:---|:---|
'''
for name, path in paths_dictionary.items():
#     print(name, '\t\t\t: ', path)
        table = table + ' | ' + name + ' | ' + path + ' | \n'
    
display(Markdown(table))
# Out:
# | Name | Path |
# |:---|:---|
#  | stock_list | /kaggle/input/jpx-tokyo-stock-exchange-prediction/stock_list.csv |
#  | sample_submission | /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/sample_submission.csv |
#  | options | /kaggle/input/jpx-tokyo-stock-exchange-prediction/supplemental_files/options.csv |
#  | financials | /kaggle/input/jpx-tokyo-stock-exchange-prediction/supplemental_files/financials.csv |
#  | secondary_stock_prices | /kaggle/input/jpx-tokyo-stock-exchange-prediction/supplemental_files/secondary_stock_prices.csv |
#  | trades | /kaggle/input/jpx-tokyo-stock-exchange-prediction/supplemental_files/trades.csv |
#  | stock_prices | /kaggle/input/jpx-tokyo-stock-exchange-prediction/supplemental_files/stock_prices.csv |
#  | competition | /kaggle/input/jpx-tokyo-stock-exchange-prediction/jpx_tokyo_market_prediction/competition.cpython-37m-x86_64-linux-gnu.so |
# ...

# %%
df_stock_list = pd.read_csv(paths_dictionary['stock_list'])

# %%
df_stock_list.shape
# Out:
# (4417, 16)

# %%
df_stock_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4417 entries, 0 to 4416
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   SecuritiesCode          4417 non-null   int64
#  1   EffectiveDate           4417 non-null   int64
#  2   Name                    4417 non-null   object
#  3   Section/Products        4417 non-null   object
#  4   NewMarketSegment        3772 non-null   object
#  5   33SectorCode            4417 non-null   object
#  6   33SectorName            4417 non-null   object
#  7   17SectorCode            4417 non-null   object
#  8   17SectorName            4417 non-null   object
#  9   NewIndexSeriesSizeCode  4417 non-null   object
#  10  NewIndexSeriesSize      4417 non-null   object
#  11  TradeDate               4121 non-null   float64
#  12  Close                   4121 non-null   float64
#  13  IssuedShares            4121 non-null   float64
# ...

# %%
df_stock_list.describe()
# Out:
#        SecuritiesCode  EffectiveDate     TradeDate          Close  \
# count     4417.000000   4.417000e+03  4.121000e+03    4121.000000
# mean      5547.191306   2.019758e+07  2.021123e+07    6376.734700
# std       2499.027227   5.196842e+04  5.106468e-01   38091.520255
# min       1301.000000   2.000010e+07  2.021122e+07       1.800000
# 25%       3423.000000   2.021123e+07  2.021123e+07     728.000000
# 50%       5711.000000   2.021123e+07  2.021123e+07    1397.000000
# 75%       7616.000000   2.021123e+07  2.021123e+07    2595.000000
# max      25935.000000   2.022022e+07  2.021123e+07  711000.000000
#
#        IssuedShares  MarketCapitalization
# count  4.121000e+03          4.121000e+03
# mean   8.992267e+07          2.184400e+11
# std    4.871675e+08          1.309481e+12
# min    2.242000e+03          3.878660e+07
# 25%    5.944100e+06          5.912841e+09
# 50%    1.495007e+07          1.822500e+10
# 75%    4.267900e+07          6.811488e+10
# ...

# %% [markdown]
# ## Working on...

# %% [markdown]
# <a href="https://www.kaggle.com/code/muhammedtausif/most-sixes-in-test-cricket-till-april-2022-eda?scriptVersionId=117829551" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <div style='background-color:#ff0000;color:yellow;font-size:50px;text-align:center;padding:20px;'>Most Sixes in Test Cricket</div>
# <div style='background-color:#0000ff;color:yellow;font-size:30px;text-align:center;padding:10px;'>EDA</div>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/most-sixes-in-test-cricket-till-april-2022/most-sixes-till-2022.csv

# %%
df = pd.read_csv('/kaggle/input/most-sixes-in-test-cricket-till-april-2022/most-sixes-till-2022.csv')

# %%
df
# Out:
#             Team   Score   4s  6s  Inns  Unnamed: 5 Result      Opposition  \
# 0    New Zealand     690   66  22     2         NaN    won      v Pakistan
# 1      Australia  735/6d   83  17     1         NaN    won      v Zimbabwe
# 2       Pakistan     643   83  15     1         NaN    won   v New Zealand
# 3          India  726/9d   76  15     2         NaN    won     v Sri Lanka
# 4   South Africa  543/6d   42  15     1         NaN  drawn   v West Indies
# 5    New Zealand     441   46  14     1         NaN    won     v Sri Lanka
# 6        England  629/6d   72  14     1         NaN  drawn  v South Africa
# 7          India  323/4d   31  14     3         NaN    won  v South Africa
# 8       Pakistan     553   58  13     2         NaN  drawn      v Zimbabwe
# 9    New Zealand     595   74  13     2         NaN    won  v South Africa
# 10      Pakistan     462   45  13     1         NaN  drawn       v England
# ...

# %%
df.shape
# Out:
# (51, 11)

# %%
df.describe()
# Out:
#               6s       Inns  Unnamed: 5
# count  51.000000  51.000000         0.0
# mean   11.901961   1.784314         NaN
# std     2.184078   0.782655         NaN
# min    10.000000   1.000000         NaN
# 25%    10.000000   1.000000         NaN
# 50%    11.000000   2.000000         NaN
# 75%    13.000000   2.000000         NaN
# max    22.000000   4.000000         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Team        51 non-null     object
#  1   Score       51 non-null     object
#  2   4s          51 non-null     object
#  3   6s          51 non-null     int64
#  4   Inns        51 non-null     int64
#  5   Unnamed: 5  0 non-null      float64
#  6   Result      51 non-null     object
#  7   Opposition  51 non-null     object
#  8   Ground      51 non-null     object
#  9   Match Date  51 non-null     object
#  10  Scorecard   51 non-null     object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 4.5+ KB

# %%
df.columns
# Out:
# Index(['Team', 'Score', '4s', '6s', 'Inns', 'Unnamed: 5', 'Result',
#        'Opposition', 'Ground', 'Match Date', 'Scorecard'],
#       dtype='object')

# %%
df.Team
# Out:
# 0      New Zealand
# 1        Australia
# 2         Pakistan
# 3            India
# 4     South Africa
# 5      New Zealand
# 6          England
# 7            India
# 8         Pakistan
# 9      New Zealand
# 10        Pakistan
# 11           India
# 12           India
# 13           India
# 14     New Zealand
# 15        Pakistan
# 16        Pakistan
# 17    South Africa
# 18    South Africa
# 19       Australia
# 20      Bangladesh
# 21     New Zealand
# 22     West Indies
# 23     New Zealand
# 24         England
# 25       Australia
# 26     West Indies
# 27        Pakistan
# 28     New Zealand
# 29       Australia
# 30        Pakistan
# 31     West Indies
# 32    South Africa
# 33       Australia
# 34       Sri Lanka
# 35           India
# 36           India
# 37     West Indies
# 38     West Indies
# 39     New Zealand
# 40        Pakistan
# 41    South Africa
# 42     West Indies
# 43         England
# 44     West Indies
# 45     West Indies
# 46       Australia
# ...

# %%
pd.DataFrame(df.Team.unique())
# Out:
#               0
# 0   New Zealand
# 1     Australia
# 2      Pakistan
# 3         India
# 4  South Africa
# 5       England
# 6    Bangladesh
# 7   West Indies
# 8     Sri Lanka

# %%
teams = df.Team.value_counts().to_frame()
teams.index.rename('Team_Name', inplace=True)
teams.rename(columns = {'Team':'Number'}, inplace = True)

# %%
teams
# Out:
#               Number
# Team_Name
# New Zealand        9
# Pakistan           9
# West Indies        9
# India              8
# Australia          6
# South Africa       5
# England            3
# Bangladesh         1
# Sri Lanka          1

# %%
teams.columns
# Out:
# Index(['Number'], dtype='object')

# %%
# plt.figure(figsize=(20,10))
# colors = sns.color_palette('bright')[0:5]
# plt.pie(teams['Number'], labels = teams['Team_name'], colors = colors, autopct='%.0f%%')
# plt.show()

# %% [markdown]
# <a href="https://www.kaggle.com/code/muhammedtausif/eda-2022-ukraine-russia-war?scriptVersionId=149593467" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style='background-color:blue; color:yellow; padding:10px; font-size:30px; text-align:center'> ___ EDA ___ </div>
# <div style='background-color:red; color:yellow; padding:20px; font-size:50px; text-align:center'> Russia vs Ukraine </div>

# %% [markdown]
# <div style='background-color:blue; color:yellow; padding:10px; font-size:20px; text-align:center'> A simple visualization about equipment and other loss on both sides.</div>

# %% [markdown]
# ## <div style='background-color:green; color:yellow; padding:10px; font-size:30px; text-align:center'> SETUP</div>

# %% [markdown]
# ## Importing Liberaries

# %%
import numpy as np 
import pandas as pd 
import os

import plotly
import plotly.graph_objs as go
import plotly.express as px
from plotly.subplots import make_subplots
import seaborn as sns

# %% [markdown]
# # Displaying all datasets links

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/the-warship-dataset/turkish_navy.json
# /kaggle/input/the-warship-dataset/russian_navy.json
# /kaggle/input/the-warship-dataset/us_navy.json
# /kaggle/input/wars-ranked-us-military-deaths/wikipedia_wars_ranked_by_total_casualties.csv
# /kaggle/input/disputed-territories/years.csv
# /kaggle/input/disputed-territories/territories.csv
# /kaggle/input/disputed-territories/states.csv
# /kaggle/input/2022-ukraine-russian-war/russia_losses_equipment.csv
# /kaggle/input/2022-ukraine-russian-war/russia_losses_equipment_correction.csv
# /kaggle/input/2022-ukraine-russian-war/russia_losses_personnel.csv
# /kaggle/input/ukrainian-airspace/ukraineflights.csv
# /kaggle/input/wars-and-fights-draft/Rplot001.png
# /kaggle/input/wars-and-fights-draft/__output__.json
# /kaggle/input/ukraine-russian-crisis-twitter-dataset-1-2-m-rows/1213_UkraineCombinedTweetsDeduped.csv.gzip
# /kaggle/input/ukraine-russian-crisis-twitter-dataset-1-2-m-rows/20230130_UkraineCombinedTweetsDeduped.csv.gzip
# ...

# %% [markdown]
# ## Loading Data

# %% [markdown]
# ### Load human losses

# %%
# Load human losses
# First day(26 of February) accumulates data for three days (24-26 February)
ru_losses_per = pd.read_csv('../input/2022-ukraine-russian-war/russia_losses_personnel.csv')

# %% [markdown]
# ### Load equipment losses

# %%
# Load equipment losses
ru_losses_eq = pd.read_csv('../input/2022-ukraine-russian-war/russia_losses_equipment.csv')

# %%
ru_losses_per, ru_losses_eq
# Out:
# (           date  day  personnel personnel*    POW
#  0    2022-02-25    2       2800      about    0.0
#  1    2022-02-26    3       4300      about    0.0
#  2    2022-02-27    4       4500      about    0.0
#  3    2022-02-28    5       5300      about    0.0
#  4    2022-03-01    6       5710      about  200.0
#  ..          ...  ...        ...        ...    ...
#  614  2023-11-01  616     301490      about    NaN
#  615  2023-11-02  617     302420      about    NaN
#  616  2023-11-03  618     303270      about    NaN
#  617  2023-11-04  619     304100      about    NaN
#  618  2023-11-05  620     305090      about    NaN
#
#  [619 rows x 5 columns],
#             date  day  aircraft  helicopter  tank   APC  field artillery  MRL  \
#  0    2022-02-25    2        10           7    80   516               49    4
#  1    2022-02-26    3        27          26   146   706               49    4
#  2    2022-02-27    4        27          26   150   706               50    4
# ...

# %% [markdown]
# ## <div style='background-color:green; color:yellow; padding:10px; font-size:30px; text-align:center'> PLOTTING</div>

# %% [markdown]
# **Human Losses**
#
# *All plots are comulative

# %% [markdown]
# Total persons lose life with respect to date

# %% [markdown]
# ### Create data

# %%
x, y = ru_losses_per['date'], ru_losses_per['personnel']

# %% [markdown]
# ### Create plot

# %%
fig = go.Figure()

# Add traces
fig.add_trace(go.Scatter(x=x, y=y,
                    mode='lines+markers',
                    name='lines+markers'))

fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# **Equipment Losses**

# %% [markdown]
# ### Create data

# %%
x = ru_losses_eq['date']
y0 = ru_losses_eq['aircraft']
y1 = ru_losses_eq['helicopter']
y2 = ru_losses_eq['anti-aircraft warfare']
y3 = ru_losses_eq['drone']

# %% [markdown]
# ### Create plot

# %%
fig = go.Figure()

# Add traces
fig.add_trace(go.Scatter(x=x, y=y0,
                    mode='lines+markers',
                    name='Aircraft'))
fig.add_trace(go.Scatter(x=x, y=y1,
                    mode='lines+markers',
                    name='Helicopter'))
fig.add_trace(go.Scatter(x=x, y=y2,
                    mode='lines+markers',
                    name='Anti-aircraft warfare'))
fig.add_trace(go.Scatter(x=x, y=y3,
                    mode='lines+markers',
                    name='Drone'))
fig.update_layout(legend_orientation="h",
                  legend=dict(x=0, y=1, traceorder="normal"),
                  title="Weapons: Air",
                  xaxis_title="Date",
                  yaxis_title="Weapons ",
                  margin=dict(l=0, r=0, t=30, b=0))
fig.show()
# Out:
# <div>                            <div id="b6df9e2f-4e48-4af2-9168-0f8b080b3e23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6df9e2f-4e48-4af2-9168-0f8b080b3e23")) {                    Plotly.newPlot(                        "b6df9e2f-4e48-4af2-9168-0f8b080b3e23",                        [{"mode":"lines+markers","name":"Aircraft","x":["2022-02-25","2022-02-26","2022-02-27","2022-02-28","2022-03-01","2022-03-02","2022-03-03","2022-03-04","2022-03-05","2022-03-06","2022-03-07","2022-03-08","2022-03-09","2022-03-10","2022-03-11","2022-03-12","2022-03-13","2022-03-14","2022-03-15","2022-03-16","2022-03-17","2022-03-18","2022-03-19","2022-03-20","2022-03-21","2022-03-22","2022-03-23","2022-03-24","2022-03-25","2022-03-26","2022-03-27","2022-03-28","202
# ...

# %% [markdown]
# ### Create data

# %%
x = ru_losses_eq['date']
y0 = ru_losses_eq['tank']
y1 = ru_losses_eq['field artillery']
y2 = ru_losses_eq['APC']
y3 = ru_losses_eq['military auto']

# %% [markdown]
# ### Create plot

# %%
fig = go.Figure()

# Add traces
fig.add_trace(go.Scatter(x=x, y=y0,
                    mode='lines+markers',
                    name='Tank'))
fig.add_trace(go.Scatter(x=x, y=y1,
                    mode='lines+markers',
                    name='Field artillery'))
fig.add_trace(go.Scatter(x=x, y=y2,
                    mode='lines+markers',
                    name='APC'))
fig.add_trace(go.Scatter(x=x, y=y3,
                    mode='lines+markers',
                    name='Military auto'))
fig.update_layout(legend_orientation="h",
                  legend=dict(x=0, y=1, traceorder="normal"),
                  title="Weapons: Ground, Other",
                  xaxis_title="Date",
                  yaxis_title="Weapons ",
                  margin=dict(l=0, r=0, t=30, b=0))
fig.show()
# Out:
# <div>                            <div id="582a8a47-d8f3-4cd8-a69e-edfb323439fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("582a8a47-d8f3-4cd8-a69e-edfb323439fb")) {                    Plotly.newPlot(                        "582a8a47-d8f3-4cd8-a69e-edfb323439fb",                        [{"mode":"lines+markers","name":"Tank","x":["2022-02-25","2022-02-26","2022-02-27","2022-02-28","2022-03-01","2022-03-02","2022-03-03","2022-03-04","2022-03-05","2022-03-06","2022-03-07","2022-03-08","2022-03-09","2022-03-10","2022-03-11","2022-03-12","2022-03-13","2022-03-14","2022-03-15","2022-03-16","2022-03-17","2022-03-18","2022-03-19","2022-03-20","2022-03-21","2022-03-22","2022-03-23","2022-03-24","2022-03-25","2022-03-26","2022-03-27","2022-03-28","2022-03
# ...

# %% [markdown]
# Realtime map: [map](https://liveuamap.com/)

# %% [markdown]
# # <div style='background-color:#111; color: white; text-align:center; padding: 10px'>END<div>

# %% [markdown]
# <a href="https://www.kaggle.com/code/muhammedtausif/ordering-formatting-dates-on-axis-seaborn?scriptVersionId=117829535" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <div style='background-color:red;color:yellow;font-size:50px;text-align:center;padding:20px;'>Ordering & Formatting Dates in Seaborn</div>

# %% [markdown]
# Loading Liberaties

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Generating Random data
# #### Seeding

# %%
# RANDOM DATA
np.random.seed(54605)
emp = pd.DataFrame({'Count': [np.random.randint(15) for _ in range(50)],
                    'Dates': pd.to_datetime(
                                          np.random.choice(
                                              pd.date_range('2022-01-01', periods=50), 
                                          50)
                                      )
                   }, columns = ['Count','Dates'])

# %% [markdown]
# #### Plotting

# %%
# PLOTTING
fig, ax = plt.subplots(figsize = (12,6))    
fig = sns.barplot(x = "Dates", y = "Count", data = emp, 
                  estimator = sum, ci = None, ax=ax)

x_dates = emp['Dates'].dt.strftime('%Y-%m-%d').sort_values().unique()
ax.set_xticklabels(labels=x_dates, rotation=45, ha='right')
# Out:
# [Text(0, 0, '2022-01-01'),
#  Text(1, 0, '2022-01-02'),
#  Text(2, 0, '2022-01-03'),
#  Text(3, 0, '2022-01-05'),
#  Text(4, 0, '2022-01-06'),
#  Text(5, 0, '2022-01-07'),
#  Text(6, 0, '2022-01-08'),
#  Text(7, 0, '2022-01-09'),
#  Text(8, 0, '2022-01-10'),
#  Text(9, 0, '2022-01-11'),
#  Text(10, 0, '2022-01-12'),
#  Text(11, 0, '2022-01-13'),
#  Text(12, 0, '2022-01-15'),
#  Text(13, 0, '2022-01-17'),
#  Text(14, 0, '2022-01-18'),
#  Text(15, 0, '2022-01-20'),
#  Text(16, 0, '2022-01-21'),
#  Text(17, 0, '2022-01-24'),
#  Text(18, 0, '2022-01-27'),
#  Text(19, 0, '2022-01-28'),
#  Text(20, 0, '2022-01-29'),
#  Text(21, 0, '2022-01-30'),
#  Text(22, 0, '2022-02-03'),
#  Text(23, 0, '2022-02-06'),
#  Text(24, 0, '2022-02-07'),
#  Text(25, 0, '2022-02-10'),
#  Text(26, 0, '2022-02-11'),
#  Text(27, 0, '2022-02-13'),
#  Text(28, 0, '2022-02-14'),
#  Text(29, 0, '2022-02-17'),
#  Text(30, 0, '2022-02-19')]
